# %%
# %matplotlib notebook
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure()
df = pd.read_csv("part2-1-early.txt")
pivot1 = df.pivot("maxLateness", "percentLate", "gatesNeeded")
sns.heatmap(pivot1, vmin=10, vmax=30, cmap="YlGnBu")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
df = pd.read_csv("part2-2-early.txt")
pivot1 = df.pivot("maxLateness", "percentLate", "gatesNeeded")
sns.heatmap(pivot1, vmin=10, vmax=30, cmap="YlGnBu")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
df = pd.read_csv("part2-1-punish.txt")
pivot1 = df.pivot("maxLateness", "percentLate", "gatesNeeded")
sns.heatmap(pivot1, vmin=10, vmax=30, cmap="YlGnBu")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
df = pd.read_csv("part2-2-punish.txt")
pivot1 = df.pivot("maxLateness", "percentLate", "gatesNeeded")
sns.heatmap(pivot1, vmin=10, vmax=30, cmap="YlGnBu")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
df = pd.read_csv("part2-1-hybrid.txt")
pivot1 = df.pivot("maxLateness", "percentLate", "gatesNeeded")
sns.heatmap(pivot1, vmin=10, vmax=30, cmap="YlGnBu")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
df = pd.read_csv("part2-2-hybrid.txt")
pivot1 = df.pivot("maxLateness", "percentLate", "gatesNeeded")
sns.heatmap(pivot1, vmin=10, vmax=30, cmap="YlGnBu")
# Out:
# <img src="data:image/png;base64,..." width="640">
