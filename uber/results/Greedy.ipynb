# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./greedy_results.csv")

plt.figure()
for m in [0, 2, 10]:
    mdata = df.loc[df['m'] == m]
    plt.plot(mdata['n'], mdata['t'], '--', label="queue len = {}".format(m))
    
plt.xlabel("Number of drivers")
plt.ylabel("Total waiting time")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.read_csv("./greedy_results.csv")

plt.figure()
for m in [0, 2, 10]:
    mdata = df.loc[df['m'] == m]
    mdata = mdata.loc[df['n'] <= 10]
    mdata = mdata.loc[1 < df['n']]
    plt.plot(mdata['n'], mdata['t'], 'o', alpha=0.5, label="queue len = {}".format(m))
    
plt.xlabel("Number of drivers")
plt.ylabel("Total waiting time")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = pd.read_csv("./greedy_supplement.csv")
df1 = df.loc[df['m'] == 0]
plt.figure()
plt.plot(df2['n'], df2['t'], 'o', alpha=0.5)
plt.plot(df1['n'], df1['t'], 'o', alpha=0.5)
plt.xlabel("Number of drivers")
plt.ylabel("Total waiting time")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = pd.read_csv("./greedy_supplement.csv")
df2 = df2.loc[df2['n'] > 1]
df1 = df.loc[df['m'] == 0]
df1 = df1.loc[df['n'] > 1]

plt.figure()
plt.plot(df1['n'], df1['t'], 'o', alpha=0.5)
plt.plot(df2['n'], df2['t'], 'o', alpha=0.5)
plt.xlabel("Number of drivers")
plt.ylabel("Total waiting time")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
