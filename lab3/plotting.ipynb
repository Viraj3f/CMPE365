# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./part1_graph.txt')
isCH = df.loc[df['isCH'] == 1]
others = df.loc[df['isCH'] == 0]
isCH = pd.concat([isCH, isCH], ignore_index=True)
plt.figure()
plt.plot(others['x'], others['y'], 'b.')
plt.plot(isCH['x'], isCH['y'], 'r-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.read_csv('./part1_graph2.txt')
isCH = df.loc[df['isCH'] == 1]
others = df.loc[df['isCH'] == 0]
isCH = pd.concat([isCH, isCH], ignore_index=True)
plt.figure()
plt.plot(others['x'], others['y'], 'b.')
plt.plot(isCH['x'], isCH['y'], 'r-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# df

# %%
df = pd.read_csv('./part1.txt')
ax = df.plot(x='n', y='c', style='.')
ax.set_xlabel('Points not in CH')
ax.set_ylabel('Point in CH')
ratio = (df['c']/(df['n'] + df['c'])).mean()
print(ratio)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.07269174581088488

# %%
df = pd.read_csv('./part2_graph.txt')
isCH = df.loc[df['isCH'] == 1]
others = df.loc[df['isCH'] == 0]
isCH = pd.concat([isCH, isCH], ignore_index=True)
plt.figure()
plt.plot(others['x'], others['y'], 'b.')
plt.plot(isCH['x'], isCH['y'], 'r-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.read_csv('./part2.txt')
ax = df.plot(x='n', y='c', style='.')
ratio = (df['c']/(df['n'] + df['c'])).mean()
ax.set_xlabel('Points not in CH')
ax.set_ylabel('Point in CH')
print(ratio)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.04827633273456385

# %%
def plotRadialCH(filename):
    f = open(filename)
    ch1_x = []
    ch1_y = []
    for pair in [line for line in f.readline().strip().split(';') if len(line) > 0]:
        x, y = pair.split(',')
        ch1_x.append(x)
        ch1_y.append(y)
    ch1_x.append(ch1_x[0])
    ch1_y.append(ch1_y[0])
        
    ch2_x = []
    ch2_y = []
    for pair in [line for line in f.readline().strip().split(';') if len(line) > 0]:
        x, y = pair.split(',')
        ch2_x.append(x)
        ch2_y.append(y)
    ch2_x.append(ch2_x[0])
    ch2_y.append(ch2_y[0])
        
    lMeanX, lMeanY = [float(x) for x in f.readline().strip().split(',')]
    lDist = float(f.readline().strip())
    
    rMeanX, rMeanY = [float(x) for x in f.readline().strip().split(',')]
    rDist = float(f.readline().strip())

    plt.figure()
    ax = plt.gca()
    ax.plot(ch1_x, ch1_y, 'r-')
    ax.plot(lMeanX, lMeanY, 'o')
    ax.plot(ch2_x, ch2_y, 'b-')
    ax.plot(rMeanX, rMeanY, 'o')
    ax.add_artist(plt.Circle((rMeanX, rMeanY), rDist, color='g', fill=False))
    ax.add_artist(plt.Circle((lMeanX, lMeanY), lDist, color='g', fill=False))
    
    print(f.readline())
    return ax

# %%
plt.figure()
plotRadialCH('part3_1.txt')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# 0

# %%
plotRadialCH('part3_2.txt')
# Out:
# <img src="data:image/png;base64,..." width="640">
# 1

# %%
plotRadialCH('part3_3.txt')
# Out:
# <img src="data:image/png;base64,..." width="640">
# 1

# %%
def plotLinearCH(filename):
    f = open(filename)
    ch1_x = []
    ch1_y = []
    for pair in [line for line in f.readline().strip().split(';') if len(line) > 0]:
        x, y = pair.split(',')
        ch1_x.append(float(x))
        ch1_y.append(float(y))
    ch1_x.append(ch1_x[0])
    ch1_y.append(ch1_y[0])
        
    ch2_x = []
    ch2_y = []
    for pair in [line for line in f.readline().strip().split(';') if len(line) > 0]:
        x, y = pair.split(',')
        ch2_x.append(float(x))
        ch2_y.append(float(y))
    ch2_x.append(ch2_x[0])
    ch2_y.append(ch2_y[0])
    
    AB_x = []
    AB_y = []
    for pair in [line for line in f.readline().strip().split(';') if len(line) > 0]:
        x, y = pair.split(',')
        AB_x.append(float(x))
        AB_y.append(float(y))

    plt.figure()
    ax = plt.gca()
    ax.plot(ch1_x, ch1_y, 'r-')
    ax.plot(ch2_x, ch2_y, 'b-')
    ax.add_artist(plt.Line2D(AB_x, AB_y, color='black', linestyle='--', linewidth=3))
    
    print(f.readline())

# %%
plotLinearCH("part4_1.txt")
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0

# %%
plotLinearCH("part4_2.txt")
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0

# %%
plotLinearCH("part4_3.txt")
# Out:
# <img src="data:image/png;base64,..." width="640">
# 1
